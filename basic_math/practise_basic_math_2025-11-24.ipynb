# %% [markdown]
# ---
# **Задача 1** \
# Дані — перегляд (хв): \
# [3, 4, 5, 6, 7]
#
# Знайти медіану.

# %%
arr = [4, 5, 3, 7, 6]

arr.sort() # sorted 
n = len(arr)
if  n % 2 == 1:
    median_ = arr[n // 2]
else:
    median_ = (arr[n // 2 - 1] + arr[n // 2]) / 2

median_
# Out:
# 5

# %% [markdown]
# ---
# **Задача 2** \
# Дані: [3, 3, 4, 100] \
# Знайти median та mean. Що про них можна сказати?

# %%
arr = [3, 3, 4, 100]
arr.sort() # sorted 
n = len(arr)
mean_ = sum(arr) / n
if  n % 2 == 1:
    median_ = arr[n // 2]
else:
    median_ = (arr[n // 2 - 1] + arr[n // 2]) / 2

print(mean_, median_)
print("У цьому наборі даних середнє значення намагаться врахувати викид. Для прийняття рішень варто орієнтуватися на медіану, оскільки вона стійка до таких стрибків.")
# Out:
# 27.5 3.5
# У цьому наборі даних середнє значення намагаться врахувати викид. Для прийняття рішень варто орієнтуватися на медіану, оскільки вона стійка до таких стрибків.

# %% [markdown]
# ---
# **Задача 3**
#
# Дані днів користування сервісом: [1, 2, 2, 2, 3, 90]
#
# Пояснити: чому median краще mean?

# %%
arr = [1, 2, 2, 2, 3, 90]
arr.sort() # sorted 
n = len(arr)
mean_ = sum(arr) / n
if  n % 2 == 1:
    median_ = arr[n // 2]
else:
    median_ = (arr[n // 2 - 1] + arr[n // 2]) / 2

print(mean_, median_)
print("В цьому випадку медіана краще покузує типове середнє")
# Out:
# 16.666666666666668 2.0
# В цьому випадку медіана краще покузує типове середнє

# %% [markdown]
# ---
# #### Moda Tasks
#
# **Задача 1** \
# Дані: [10, 12, 12, 15, 20]\
# Знайти моду.

# %%
arr = [10, 12, 12, 15, 20]
dic = {}
for i in arr:
    if i in dic.keys():
        dic[i] += 1
    else:
        dic[i] = 1
max_ = max(dic.values())
lst_mode = []
for i in arr:
    if dic[i] == max_:
        lst_mode.append(i)
print(max_)
print(lst_mode)
# Out:
# 2
# [12, 12]

# %% [markdown]
# ---
# Задача 2
#
# Кількість подій на користувача:
# [1,1,1,2,3,100]

# %%
from collections import Counter
arr = [1,1,1,2,3,100]
dic = Counter(arr)

arr.sort() # sorted 
n = len(arr)
mean_ = sum(arr) / n
if  n % 2 == 1:
    median_ = arr[n // 2]
else:
    median_ = (arr[n // 2 - 1] + arr[n // 2]) / 2
print(f"Mean = {mean_}, Median =  {median_}, Mode = {dic.most_common()}")
# Out:
# Mean = 18.0, Median =  1.5, Mode = [(1, 3), (2, 1), (3, 1), (100, 1)]

# %% [markdown]
# ---
# Середнє - avg
#
# Дані: [1,2,3,4]

# %%
arr = [1,2,3,4]
print("Середнє - avg =", sum(arr) /len(arr))
# Out:
# Середнє - avg = 2.5

# %% [markdown]
# ---
# Розмах
#
# Час поставки:
# [3, 4, 5, 6, 7, 120, 130]

# %%
data = [3, 4, 5, 6, 7, 120, 130]
data_range = max(data) - min(data)
print(f"Розмах: {data_range}") # 130 - 3 = 127
# Out:
# Розмах: 127

# %% [markdown]
# ---
# Дисперсія
#
# # Задача 1
# Дані: [2, 4, 6, 8]
#
# Потрібно:
# - знайти середнє
# - знайти квадрати відхилень
# - знайти дисперсію
# - інтерпретувати результат

# %%
data = [2, 4, 6, 8]
mean = sum(data) / len(data)
variance = sum((x - mean) ** 2 for x in data) / len(data)
print(f"Середнє: {mean}, Дисперсія: {variance}")
# Out:
# Середнє: 5.0, Дисперсія: 5.0

# %% [markdown]
# Задача 2 — два набори з однаковим середнім, але різним розкидом \
# A: [4, 5, 6] \
# B: [1, 5, 9]
#
# Середні однакові.
# Який набір стабільніший?

# %%
a_set = [4, 5, 6]
b_set = [1, 5, 9]
def var_my(arr):
    n = len(arr)
    mean_ = sum(arr) / n
    return sum((i - mean_) ** 2 for i in arr) / n
print(var_my(a_set), var_my(b_set))
print('Набір А стабільніший.')
# Out:
# 0.6666666666666666 10.666666666666666
# Набір А стабільніший.

# %% [markdown]
# ---
# ### Std
# Дані: [4, 5, 6, 9, 10]
#
# Порахуй variance і std.

# %%
arr = [4, 5, 6, 9, 10]
def var_my(arr):
    n = len(arr)
    mean_ = sum(arr) / n
    return sum((i - mean_) ** 2 for i in arr) / n
print("Дисперсія (Variance):",var_my(arr), "Стандартне відхилення (Std):", var_my(arr) ** 0.5)
# Out:
# Дисперсія (Variance): 5.36 Стандартне відхилення (Std): 2.3151673805580453
